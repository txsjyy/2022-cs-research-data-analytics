# %%
# import packages
import numpy as np
import pandas as pd

# %%
# import data set
apdata = pandas.read_csv('airports.csv')
ftdata = pandas.read_csv('flights.csv')
# Out:
# /Users/junyuyao/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
apdata.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
ftdata.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
apdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  322 non-null    object
#  1   AIRPORT    322 non-null    object
#  2   CITY       322 non-null    object
#  3   STATE      322 non-null    object
#  4   COUNTRY    322 non-null    object
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 17.7+ KB

# %%
ftdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %% [markdown]
# ## Q1 Find a list of Origin Airports

# %%
df1 = ftdata['ORIGIN_AIRPORT'].unique()
l1 = list(df1)
l1
# Out:
# ['ANC',
#  'LAX',
#  'SFO',
#  'SEA',
#  'LAS',
#  'DEN',
#  'SLC',
#  'PDX',
#  'FAI',
#  'MSP',
#  'PHX',
#  'SJU',
#  'PBG',
#  'IAG',
#  'PSE',
#  'BQN',
#  'ORD',
#  'GEG',
#  'HNL',
#  'ONT',
#  'MCO',
#  'BOS',
#  'HIB',
#  'ABR',
#  'MAF',
#  'DFW',
#  'MKE',
#  'IAH',
#  'BNA',
#  'BRO',
#  'VPS',
#  'BOI',
#  'BJI',
#  'SGF',
#  'PHL',
#  'SBN',
#  'RDD',
#  'EUG',
#  'IAD',
#  'BUF',
#  'PWM',
#  'JFK',
#  'CRP',
#  'PIA',
#  'FAT',
#  'SMF',
#  'AUS',
#  'MCI',
#  'ATL',
#  'JAX',
#  'MFR',
#  'IDA',
#  'MSN',
#  'DCA',
#  'SAT',
#  'CHS',
#  'SBA',
#  'SMX',
#  'IND',
#  'CLE',
#  'GSP',
#  'BDL',
#  'ABI',
#  'RIC',
#  'BFL',
#  'OMA',
#  'RDM',
#  'FLL',
#  'CID',
#  'TPA',
#  'SYR',
#  'ROC',
#  'TYR',
#  'LAN',
#  'XNA',
#  'GSO',
#  'EWR',
#  'PBI',
#  'RSW',
#  'OAK',
#  'PVD',
#  'RNO',
#  'PIT',
#  'ABQ',
#  'MIA',
#  'BWI',
#  'LGA',
#  'TUL',
#  'LIT',
#  'MSY',
#  'OKC',
#  'ATW',
#  'PNS',
#  'MEM',
#  'TYS',
#  'MHT',
#  'SAV',
#  'CLT',
#  'GRB',
#  'ABE',
# ...

# %% [markdown]
# ## Q2 Find a list of (Origin, Destination) pairs

# %%
df2 = ftdata[['ORIGIN_AIRPORT','DESTINATION_AIRPORT']]
df2_1 = df2.drop_duplicates()
df2_1
# Out:
#         ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0                  ANC                 SEA
# 1                  LAX                 PBI
# 2                  SFO                 CLT
# 3                  LAX                 MIA
# 4                  SEA                 ANC
# ...                ...                 ...
# 5796607            GSP                 MIA
# 5799339            MIA                 OKC
# 5801064            LRD                 HRL
# 5802350            OKC                 MIA
# 5814476            CID                 LAX
#
# [12377 rows x 2 columns]

# %% [markdown]
# ## Q3 Find the Origin airport which had the largest departure delay in the month of January

# %%
flights_in_jan=ftdata[ftdata['MONTH']==1]

max_delay_flight=flights_in_jan[flights_in_jan['DEPARTURE_DELAY'] >= flights_in_jan['DEPARTURE_DELAY'].max()]

print(max_delay_flight['ORIGIN_AIRPORT'])
# Out:
# 337720    BHM
# Name: ORIGIN_AIRPORT, dtype: object

# %% [markdown]
# ## Q4 Find out which carrier has the largest delay on Weekends.

# %%
df4 = ftdata[ftdata['DAY_OF_WEEK'].isin([6,7])]

df4_1 = df4.nlargest(1,['DEPARTURE_DELAY'])

df4_1[['DEPARTURE_DELAY', 'AIRLINE','FLIGHT_NUMBER']]
# Out:
#          DEPARTURE_DELAY AIRLINE  FLIGHT_NUMBER
# 3412085           1878.0      AA             96

# %% [markdown]
# ## Q5 Which airport has the most cancellation of flights?

# %%
df5 = ftdata[ftdata['CANCELLED']==1]

destinations = df5['DESTINATION_AIRPORT'].value_counts()

origin = df5['ORIGIN_AIRPORT'].value_counts()


print('destination airport', destinations.nlargest(1))
print('origin airport', origin.nlargest(1))
# Out:
# destination airport ORD    9273
# Name: DESTINATION_AIRPORT, dtype: int64
# origin airport ORD    8548
# Name: ORIGIN_AIRPORT, dtype: int64

# %% [markdown]
# ## Q6 Find the percent of flights cancelled for each carrier.

# %%
df6 = ftdata.groupby('AIRLINE').mean()['CANCELLED']
print(df6)
df6.nlargest(1)
# Out:
# AIRLINE
# AA    0.015040
# AS    0.003878
# B6    0.016012
# DL    0.004366
# EV    0.026629
# F9    0.006473
# HA    0.002242
# MQ    0.050996
# NK    0.017073
# OO    0.016929
# UA    0.012745
# US    0.020466
# VX    0.008626
# WN    0.012714
# Name: CANCELLED, dtype: float64
# AIRLINE
# MQ    0.050996
# Name: CANCELLED, dtype: float64

# %% [markdown]
# ## Q7 Find the largest departure delay for each carrier

# %%
df7 = ftdata.groupby('AIRLINE').max()['DEPARTURE_DELAY']
print(df7)
df7.nlargest(1)
# Out:
# AIRLINE
# AA    1988.0
# AS     963.0
# B6    1006.0
# DL    1289.0
# EV    1274.0
# F9    1112.0
# HA    1433.0
# MQ    1544.0
# NK     836.0
# OO    1378.0
# UA    1314.0
# US     759.0
# VX     644.0
# WN     665.0
# Name: DEPARTURE_DELAY, dtype: float64
# /var/folders/vv/lx8h54050gx2ndymzg8v1gm40000gn/T/ipykernel_11071/3527714363.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df7 = ftdata.groupby('AIRLINE').max()['DEPARTURE_DELAY']
# AIRLINE
# AA    1988.0
# Name: DEPARTURE_DELAY, dtype: float64

# %% [markdown]
# ## Q8 Find the largest departure delay for each carrier for each month

# %%
for i in range(1,12):
    df8 = ftdata[ftdata['MONTH'] == i]
    df8_1 = df8.groupby('AIRLINE').max()['DEPARTURE_DELAY']
    print('Month',i,df8_1)
# Out:
# /var/folders/vv/lx8h54050gx2ndymzg8v1gm40000gn/T/ipykernel_11071/2931140902.py:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df8_1 = df8.groupby('AIRLINE').max()['DEPARTURE_DELAY']
# Month 1 AIRLINE
# AA    1988.0
# AS     538.0
# B6     500.0
# DL    1184.0
# EV     726.0
# F9     696.0
# HA    1003.0
# MQ     780.0
# NK     557.0
# OO     931.0
# UA     886.0
# US     638.0
# VX     397.0
# WN     604.0
# Name: DEPARTURE_DELAY, dtype: float64
# Month 2 AIRLINE
# AA    1587.0
# AS     735.0
# B6     942.0
# DL    1159.0
# EV     600.0
# F9     852.0
# HA    1433.0
# MQ    1154.0
# NK     546.0
# OO     913.0
# UA     858.0
# US     536.0
# VX     577.0
# WN     506.0
# Name: DEPARTURE_DELAY, dtype: float64
# Month 3 AIRLINE
# AA    1609.0
# AS     868.0
# B6     674.0
# DL    1166.0
# EV     583.0
# F9    1112.0
# ...

# %% [markdown]
# ## Q9 For each carrier find the average Departure delay

# %%
df7 = ftdata.groupby('AIRLINE').mean()['DEPARTURE_DELAY']
df7
# Out:
# AIRLINE
# AA     8.900856
# AS     1.785801
# B6    11.514353
# DL     7.369254
# EV     8.715934
# F9    13.350858
# HA     0.485713
# MQ    10.125188
# NK    15.944766
# OO     7.801104
# UA    14.435441
# US     6.141137
# VX     9.022595
# WN    10.581986
# Name: DEPARTURE_DELAY, dtype: float64

# %% [markdown]
# ## Q10 For each carrier find the average Departure delay for each month

# %%
df10_2 = pd.DataFrame
for i in range(1,12):
    df10 = ftdata[ftdata['MONTH'] == i]
    df10_1 = df10.groupby('AIRLINE').mean()['DEPARTURE_DELAY']
    print('Month',i,df10_1)
# Out:
# Month 1 AIRLINE
# AA    10.593542
# AS     3.178209
# B6    10.035556
# DL     5.904238
# EV     9.752522
# F9    17.984433
# HA     1.310065
# MQ    16.081207
# NK    13.146294
# OO    12.155157
# UA    14.010359
# US     5.197315
# VX     6.910772
# WN     9.514470
# Name: DEPARTURE_DELAY, dtype: float64
# Month 2 AIRLINE
# AA    10.258853
# AS     2.703814
# B6    19.665223
# DL    12.226444
# EV    11.230904
# F9    25.710005
# HA     2.580506
# MQ    18.600579
# NK    16.958248
# OO    10.954536
# UA    14.907992
# US     9.123066
# VX    12.600540
# WN     9.860234
# Name: DEPARTURE_DELAY, dtype: float64
# Month 3 AIRLINE
# AA    11.086628
# AS     3.063562
# B6    15.173697
# DL     8.443340
# EV     8.892073
# F9    20.011169
# HA     0.824024
# MQ    12.310134
# NK    12.613168
# OO     5.847798
# UA    13.960860
# US     5.955991
# VX    10.592154
# WN    10.132266
# Name: DEPARTURE_DELAY, dtype: float64
# Month 4 AIRLINE
# AA    10.555278
# AS     0.004242
# ...

# %% [markdown]
# ## Q11 Which date of year has the highest rate of flight cancellations? Rate of flight cancellation is calculated by deviding number of canceled flights by total number of flights.

# %%
df11 = ftdata.groupby(['MONTH','DAY']).mean()['CANCELLED']
print(df11)
df11.nlargest(1)
# Out:
# MONTH  DAY
# 1      1      0.033405
#        2      0.015352
#        3      0.021446
#        4      0.026480
#        5      0.026287
#                 ...
# 12     27     0.070144
#        28     0.133460
#        29     0.042287
#        30     0.017282
#        31     0.003198
# Name: CANCELLED, Length: 365, dtype: float64
# MONTH  DAY
# 1      27     0.1903
# Name: CANCELLED, dtype: float64

# %% [markdown]
# ## Q12 Calculate the number of flights to each destination state For each carrier, for which state do they have the largest average delay?

# %%
df12 = ftdata['AIRLINE'].unique()
l12 = list(df12)
for i in l12:
    df12_1 = ftdata[ftdata['AIRLINE'] == i]
    df12_2 = df12_1.groupby('DESTINATION_AIRPORT').count()['FLIGHT_NUMBER']
    print(i,df12_2)
# Out:
# AS DESTINATION_AIRPORT
# 10140     29
# 10165      9
# 10170     29
# 10299    935
# 10397     58
#         ...
# STL      399
# TPA      334
# TUS      347
# WRG      664
# YAK      662
# Name: FLIGHT_NUMBER, Length: 191, dtype: int64
# AA DESTINATION_AIRPORT
# 10140     174
# 10257      80
# 10299      32
# 10397     916
# 10423     785
#          ...
# SYR       271
# TPA      8203
# TUL      2324
# TUS      2789
# XNA        18
# Name: FLIGHT_NUMBER, Length: 274, dtype: int64
# US DESTINATION_AIRPORT
# ABQ      49
# ALB     359
# ANC     165
# ATL    2940
# AUS     469
#        ...
# STT     364
# STX      22
# SYR     321
# TPA    3553
# TUS       3
# Name: FLIGHT_NUMBER, Length: 79, dtype: int64
# DL DESTINATION_AIRPORT
# 10135      29
# 10140     144
# 10208      29
# 10257     137
# 10299     137
#          ...
# TUS       796
# TVC       425
# TYS       937
# VPS      1765
# XNA       539
# Name: FLIGHT_NUMBER, Length: 439, dtype: int64
# NK DESTINATION_AIRPORT
# ...

# %%
for i in l12:
    df12_1 = ftdata[ftdata['AIRLINE'] == i]
    df12_3 = df12_1.groupby('DESTINATION_AIRPORT').mean()['CANCELLED']
    print(i, df12_3.nlargest(1))
# Out:
# AS DESTINATION_AIRPORT
# 15991    0.25
# Name: CANCELLED, dtype: float64
# AA DESTINATION_AIRPORT
# 10423    0.428571
# Name: CANCELLED, dtype: float64
# US DESTINATION_AIRPORT
# LGA    0.083476
# Name: CANCELLED, dtype: float64
# DL DESTINATION_AIRPORT
# 10868    0.02381
# Name: CANCELLED, dtype: float64
# NK DESTINATION_AIRPORT
# 13796    0.1
# Name: CANCELLED, dtype: float64
# UA DESTINATION_AIRPORT
# 10423    0.227273
# Name: CANCELLED, dtype: float64
# HA DESTINATION_AIRPORT
# SFO    0.007485
# Name: CANCELLED, dtype: float64
# B6 DESTINATION_AIRPORT
# 10423    0.833333
# Name: CANCELLED, dtype: float64
# OO DESTINATION_AIRPORT
# 10423    0.785714
# Name: CANCELLED, dtype: float64
# EV DESTINATION_AIRPORT
# 13158    0.5
# Name: CANCELLED, dtype: float64
# MQ DESTINATION_AIRPORT
# 12915    0.4
# Name: CANCELLED, dtype: float64
# F9 DESTINATION_AIRPORT
# 10423    0.428571
# Name: CANCELLED, dtype: float64
# WN DESTINATION_AIRPORT
# 10423    0.333333
# ...
