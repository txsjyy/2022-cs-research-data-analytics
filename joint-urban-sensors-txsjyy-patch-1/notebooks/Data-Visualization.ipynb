# %%
# Libraries required
import pandas as pd
import os

# %%
# Path to the files
pwd = 'dataset-samples/'
os.chdir(pwd)

# %%
# Read in one csv file and 
df = pd.read_csv('I01R1V0.CSV', 
                 names=
                    ['Day_of_Year',
                    'UTC_Hours',
                    'UTC_Minutes',
                    'UTC_seconds',
                    'IOP_number',
                    'van_number',
                    'pass_number',
                    'hours_in_CDT_day_start',
                    'latitude',
                    'longitude', 
                    'altitude',
                    'number_of_satellites',
                    'hdop',
                    'concentration_of_SF6',
                    'QC_flag'])

# %%
df
# Out:
#        Day_of_Year  UTC_Hours  UTC_Minutes  UTC_seconds  IOP_number  \
# 0              180         14            0          0.0           1
# 1              180         14            0          0.5           1
# 2              180         14            0          1.0           1
# 3              180         14            0          1.5           1
# 4              180         14            0          2.0           1
# ...            ...        ...          ...          ...         ...
# 10796          180         15           29         58.0           1
# 10797          180         15           29         58.5           1
# 10798          180         15           29         59.0           1
# 10799          180         15           29         59.5           1
# 10800          180         15           30          0.0           1
#
#        van_number  pass_number  hours_in_CDT_day_start   latitude  longitude  \
# ...
